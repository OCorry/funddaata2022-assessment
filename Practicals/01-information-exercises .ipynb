# %%
#code to generate a 1000 character long string with weights based on previous two characters
#for this I am adapting code from: https://github.com/ianmcloughlin/2223-S1-fund-data-analysis/blob/main/notebooks/01-information.ipynb

# Make HTTP requests for internet reqources.
import urllib.request

# The URL of a text version of Alice in Wonderland.
book_url = 'https://www.gutenberg.org/files/11/11-0.txt'

# Get the book.
book = list(urllib.request.urlopen(book_url))

# Decode the lines and strip line endings.
book = [line.decode('utf-8-sig').strip() for line in book]

# Get a sample paragraph - took a big enough sample so I can take 1000 characters from it.
paragraph = ' '.join(book[100:250])

# Show the paragraph.
print(paragraph)
# Out:
# cupboards as she fell past it.  “Well!” thought Alice to herself, “after such a fall as this, I shall think nothing of tumbling down stairs! How brave they’ll all think me at home! Why, I wouldn’t say anything about it, even if I fell off the top of the house!” (Which was very likely true.)  Down, down, down. Would the fall _never_ come to an end? “I wonder how many miles I’ve fallen by this time?” she said aloud. “I must be getting somewhere near the centre of the earth. Let me see: that would be four thousand miles down, I think—” (for, you see, Alice had learnt several things of this sort in her lessons in the schoolroom, and though this was not a _very_ good opportunity for showing off her knowledge, as there was no one to listen to her, still it was good practice to say it over) “—yes, that’s about the right distance—but then I wonder what Latitude or Longitude I’ve got to?” (Alice had no idea what Latitude was, or Longitude either, but thought they were nice grand words to say.
# ...

# %%
# changing all of the paragraph to lower case letters.
alice = paragraph.lower()

# #using all lower case letters of the alphabet and space character 
chars = 'abcdefghijklmnopqrstuvwxyz '

#stripping any character that is not a letter or space.
alice = ''.join([c for c in alice if c in chars])

# Show the updated paragraph with only letters and space charcters 
print(alice)
# Out:
# cupboards as she fell past it  well thought alice to herself after such a fall as this i shall think nothing of tumbling down stairs how brave theyll all think me at home why i wouldnt say anything about it even if i fell off the top of the house which was very likely true  down down down would the fall never come to an end i wonder how many miles ive fallen by this time she said aloud i must be getting somewhere near the centre of the earth let me see that would be four thousand miles down i think for you see alice had learnt several things of this sort in her lessons in the schoolroom and though this was not a very good opportunity for showing off her knowledge as there was no one to listen to her still it was good practice to say it over yes thats about the right distancebut then i wonder what latitude or longitude ive got to alice had no idea what latitude was or longitude either but thought they were nice grand words to say  presently she began again i wonder if i shall fall rig
# ...

# %%
#extracting character 1 up to but not including character 1000 from the sliced paragraph and giving it the variable name characters
characters = alice [1:1000]
#printing 999 characters from the paragraph 
print (characters)
# Out:
# upboards as she fell past it  well thought alice to herself after such a fall as this i shall think nothing of tumbling down stairs how brave theyll all think me at home why i wouldnt say anything about it even if i fell off the top of the house which was very likely true  down down down would the fall never come to an end i wonder how many miles ive fallen by this time she said aloud i must be getting somewhere near the centre of the earth let me see that would be four thousand miles down i think for you see alice had learnt several things of this sort in her lessons in the schoolroom and though this was not a very good opportunity for showing off her knowledge as there was no one to listen to her still it was good practice to say it over yes thats about the right distancebut then i wonder what latitude or longitude ive got to alice had no idea what latitude was or longitude either but thought they were nice grand words to say  presently she began again i wonder if i shall fall righ
# ...

# %%
#checking there are 999 characters in the sliced sample above (so that my final output will be 1000 characters as per the brief)
N = len (characters)
print (N)
# Out:
# 999

# %%
# Get the whole book in one big string - so the weights will be applied based on the full book 
sbook = ''.join(book[26:]).lower()

# Create the weights - count the occurences of each character in the whole book.
weights = [sbook.count(c) for c in chars]

# Show the weights.
weights
# Out:
# [9801,
#  1743,
#  3008,
#  5455,
#  15402,
#  2374,
#  2938,
#  7902,
#  8611,
#  232,
#  1291,
#  5194,
#  2459,
#  8032,
#  9471,
#  1971,
#  223,
#  6617,
#  7246,
#  12225,
#  3970,
#  962,
#  2958,
#  181,
#  2592,
#  80,
#  26950]

# %%
# Generate a string using those weights.
wgenr = random.choices(chars, weights=weights, k=N)

# Join them together in a string.
wgenr = ''.join(wgenr)

# Print.
print(wgenr)
# Out:
# p  ohdwtrnm r nse lswnbhi ar tivnnteie tm i rnmueweteenf  mu ln tc itgtmt etldtp  inp wecxlpodtnh ir smi aae faas ndsten   epagsirwiereurxhltarwen  nhat h  gnholn oeineenbevnc ocfh eeeortes qr m nasucveteonne oosts nluhftvdhn lher eesenaod elousha ho teono d oeo iacohotgl t hhdhturcyiassih iltlu snoeecdanh  idehnqtrnln uk  er al  e  gehairnot na cifnwens rhdiknowfeso tuhlsapgj ithekf d slalapne mteu yeyh drg ctktut ioathtod nyat tooril ita de i caet r  yuoe  tc shiah otui motdewh  g shnsdwienrtob t irtngrn dadi  crne bfatuak  rherwas tlr hre  ylnmhetemhnaoth kodeen c t o orgwre isepgsss si rattigiimdn m mainhtkwb  i ni sm ci el   dw ord ehnri  i hislteteahsrlkddlyn v dpedorcha ea  sndhheo bhsir liedgs rtlu hefste lta see eh oiu   u neinhehpesu seorml  vphthlky tleehe rdslie nsru ecsento ykt naeib ctdamtumdorefeaye s tdtonofnwryxheovh zoensmef noketddguacf afrbr  eeeiowdh oaeoneapusuhshurtipunuenrgg tesda s tcn  r rmoeu   en olrlioieuaesdlati loe ied l brt hi tboesu o au  ao e ebtnsgt
# ...

# %%
# Create the weights.
twoghts = {c: {d: sbook.count(c + d) for d in chars} for c in chars}

# Show the weights.
twoghts
# Out:
# {'a': {'a': 0,
#   'b': 243,
#   'c': 208,
#   'd': 482,
#   'e': 1,
#   'f': 68,
#   'g': 220,
#   'h': 30,
#   'i': 752,
#   'j': 12,
#   'k': 131,
#   'l': 1018,
#   'm': 202,
#   'n': 1776,
#   'o': 3,
#   'p': 147,
#   'q': 0,
#   'r': 846,
#   's': 944,
#   't': 1345,
#   'u': 80,
#   'v': 178,
#   'w': 96,
#   'x': 12,
#   'y': 294,
#   'z': 5,
#   ' ': 660},
#  'b': {'a': 82,
#   'b': 68,
#   'c': 0,
#   'd': 1,
#   'e': 651,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 122,
#   'j': 8,
#   'k': 0,
#   'l': 124,
#   'm': 1,
#   'n': 0,
#   'o': 228,
#   'p': 0,
#   'q': 0,
#   'r': 62,
#   's': 35,
#   't': 13,
#   'u': 239,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 101,
#   'z': 0,
#   ' ': 3},
#  'c': {'a': 353,
#   'b': 0,
#   'c': 36,
#   'd': 0,
#   'e': 796,
#   'f': 0,
#   'g': 0,
#   'h': 517,
#   'i': 56,
#   'j': 0,
#   'k': 182,
#   'l': 87,
#   'm': 0,
#   'n': 0,
#   'o': 455,
#   'p': 0,
#   'q': 0,
#   'r': 125,
#   's': 1,
#   't': 236,
#   'u': 113,
# ...

# %%
# Loop through our character set.
for i in range(len(chars)):
    # Print the character and how many times it appears in Alice in Wonderland.
    print(f'{chars[i]}: {weights[i]}')
# Out:
# a: 9801
# b: 1743
# c: 3008
# d: 5455
# e: 15402
# f: 2374
# g: 2938
# h: 7902
# i: 8611
# j: 232
# k: 1291
# l: 5194
# m: 2459
# n: 8032
# o: 9471
# p: 1971
# q: 223
# r: 6617
# s: 7246
# t: 12225
# u: 3970
# v: 962
# w: 2958
# x: 181
# y: 2592
# z: 80
#  : 26950

# %%
# Starting with characters o and c.
pairs = 'oc'

# Do the following N-2 times.
for i in range(1, N):
    # Get the weights where the previous two characters are the last characters in twos.
    wt = twoghts[pairs[-2]]
    # Turn wt into a list, ordered by chars.
    wt = [wt[c] for c in chars]
    # Randomly pick the next character using those weights.
    nextc = random.choices(chars, weights=wt, k=1)[0]
    # Append the character to twos.
    pairs = pairs + nextc

# %%
pairs
# Out:
# 'occa andivapryondr bshar tonghe hepeshalag okyo inder bu fow wnghed s sor areche re f tt tengeralyordopsampe merw wigzy achindng pepe atmok be me m y t quingu tse marse f t pinyo ontor outeruted whallis oweithe alf ssoutthis hat bouer lethe pasiutif terenpurtepaspitrid hacoueve wetitino wodeass berocoulinndie th sangas biowano maubigr g s tha atoen tthe muiche mathe therthe nd inulanennguts wayemit taved an asereemigrgrealiro ly d ffoutoree thind ve o wapererg gingoropidilithibyo sas rk tututurrin pererinoneine yongren tost t id ooowepe owabit hery lin s dd ow shar ker ag tut rdlino ilyorsiteve wnge astitin  rpou aiththerave me ginthoo hisrooidiner crr in henaugontheserncethas scrme seak h sury f t h erse t terume attro kn ave ainge ullsutho ulthathi hocory a por bidy di hotheat tofe r outraro tive se ly thoras pond yend thaitlyote k lly abbl barheseho ichere w gerin aiveryo alereit yo a fechegutththeawin ath fo us s t sthed nuicr meremes ark t oventhte tfeans m tuthit hesay tangeme
# ...

# %%
#checking that my final output is 1000 characters long 
len(pairs)
# Out:
# 1000
